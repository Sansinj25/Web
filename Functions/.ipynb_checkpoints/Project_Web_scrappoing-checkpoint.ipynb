# %%
import numpy as np
import pandas as pd
import re
import nltk
import itertools
from nltk.corpus import wordnet as wn
from nltk import pos_tag
from nltk.tag import UnigramTagger
from nltk.corpus import brown
import requests
from bs4 import BeautifulSoup
import string
from nltk.stem import WordNetLemmatizer

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
ingredient=[]
ingred_unities=[]

categories=['Vegetables+and+Vegetable+Products','Cereal+Grains+and+Pasta','Dairy+and+Egg+Products',\
            'Poultry+Products','Fats+and+Oils','Spices+and+Herbs','Fruits+and+Fruit+Juices',\
            'Legumes+and+Legume+Products','Nut+and+Seed+Products','Pork+Products','Beef+Products',\
            'Lamb%2C+Veal%2C+and+Game+Products','Sweets','Baked+Products']
page_numbers={categories[0]:35,categories[1]:19,categories[2]:25,categories[3]:25,categories[4]:19,\
             categories[5]:6,categories[6]:25,categories[7]:25,categories[8]:10,categories[9]:4,\
              categories[10]:4,categories[11]:4,categories[12]:6,categories[13]:3}

for cat in categories:
    print(cat)
    sum_ingr_added=0
    for i in range(1,page_numbers[cat]+1):
        url='https://www.nutritionvalue.org/search.php?category='+cat+'&page='+str(i)
        r=requests.get(url,headers=headers)
        page_body = r.text
        soup=BeautifulSoup(page_body, 'html.parser')
        stat= soup.find('table', class_="full_width results zero")
        ingr_added=0
        for ingred in stat.find_all('td',class_="results left"):
            a=ingred.find('a')
            ingr_name=a.get('title')
            ingredient.append(ingr_name)
            url2='https://www.nutritionvalue.org'+a.get('href')
            r=requests.get(url2,headers=headers)
            page_body = r.text
            soup=BeautifulSoup(page_body, 'html.parser')
            selec=soup.find('select')
            if selec:
                ingr_added+=1
            dic_values={}
            for q in selec.find_all('option'):
                ratios_values=q.get('value').split('=')
                if len(ratios_values)>1:
                    dic_values[ratios_values[0]]=ratios_values[1]
                else:
                    dic_values[ratios_values[0]]=np.nan
            ingred_unities.append(dic_values)
        print('ingredients ajoutés:',ingr_added)
        sum_ingr_added+=ingr_added
    print('Total ingredients in: ' ,cat,'is :',sum_ingr_added)
# Out:
# Vegetables+and+Vegetable+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Vegetables+and+Vegetable+Products is : 350
# Cereal+Grains+and+Pasta
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 1
# Total ingredients in:  Cereal+Grains+and+Pasta is : 181
# Dairy+and+Egg+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Dairy+and+Egg+Products is : 250
# Poultry+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Poultry+Products is : 250
# Fats+and+Oils
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Fats+and+Oils is : 190
# Spices+and+Herbs
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Spices+and+Herbs is : 60
# Fruits+and+Fruit+Juices
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Fruits+and+Fruit+Juices is : 250
# Legumes+and+Legume+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Legumes+and+Legume+Products is : 250
# Nut+and+Seed+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Nut+and+Seed+Products is : 100
# Pork+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Pork+Products is : 40
# Beef+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Beef+Products is : 40
# Lamb%2C+Veal%2C+and+Game+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Lamb%2C+Veal%2C+and+Game+Products is : 40
# Sweets
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Sweets is : 60
# Baked+Products
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# ingredients ajoutés: 10
# Total ingredients in:  Baked+Products is : 30

# %%
lemmatizer = WordNetLemmatizer()
ingredient=[lemmatizer.lemmatize(token).lower() for token in ingredient]

# %%
ingredients_units=pd.DataFrame(data=ingred_unities,index=ingredient)
display(ingredients_units.head())
# Out:
#           .1 fruit  .167 package (5.5 oz)  .2 block  .2 head  .2 package   \
# poi             NaN                    NaN       NaN      NaN         NaN
# catsup          NaN                    NaN       NaN      NaN         NaN
# yam, raw        NaN                    NaN       NaN      NaN         NaN
# taro, raw       NaN                    NaN       NaN      NaN         NaN
# okra, raw       NaN                    NaN       NaN      NaN         NaN
#
#           .25 block  .25 cup  .25 cup drained  .25 cup leaves, whole   \
# poi              NaN      NaN              NaN                    NaN
# catsup           NaN      NaN              NaN                    NaN
# yam, raw         NaN      NaN              NaN                    NaN
# taro, raw        NaN      NaN              NaN                    NaN
# okra, raw        NaN      NaN              NaN                    NaN
#
#           .25 cup shredded     ...    50 raisins  6 fl oz  6 pieces   \
# poi                     NaN    ...            NaN      NaN       NaN
# catsup                  NaN    ...            NaN      NaN       NaN
# yam, raw                NaN    ...            NaN      NaN       NaN
# taro, raw               NaN    ...            NaN      NaN       NaN
# okra, raw               NaN    ...            NaN      NaN       NaN
#
#           6 slices  60 milliliter  8 caps  8 fl oz  8 oz  8 pods (3" long)   \
# poi             NaN            NaN     NaN      NaN   NaN               NaN
# catsup          NaN            NaN     NaN      NaN   NaN               NaN
# yam, raw        NaN            NaN     NaN      NaN   NaN               NaN
# taro, raw       NaN            NaN     NaN      NaN   NaN               NaN
# okra, raw       NaN            NaN     NaN      NaN   NaN              95 g
#
#           9 sprigs
# poi             NaN
# catsup          NaN
# yam, raw        NaN
# taro, raw       NaN
# okra, raw       NaN
#
# [5 rows x 778 columns]

# %%
len(ingredient)
Vegi=ingredient[0:350]
Cereal=ingredient[350:531]
Dairy=ingredient[531:781]
Poultry=ingredient[781:1031]
Fats=ingredient[1031:1221]
Spices=ingredient[1221:1281]
Fruits=ingredient[1281:1531]
Legumes=ingredient[1531:1781]
Nuts=ingredient[1781:1881]
Pork=ingredient[1881:1921]
Beef=ingredient[1921:1961]
Lamb=ingredient[1961:2001]
Sweet=ingredient[2001:2061]
Baked=ingredient[2061:2091]

# %%
with open('ingredient_list.txt', 'r') as f:
    ingredient_list = [line.rstrip('\n') for line in f]
    
lemmatizer = WordNetLemmatizer()
ingredient_list=[lemmatizer.lemmatize(token).lower() for token in ingredient_list]

# %%
#      option 1
##  TAKE ELEM THAT WE ALREADY HAVE:
categ_list=[Vegi,Cereal,Dairy,Poultry,Fats,Spices,Fruits,Legumes,Nuts,Pork,Beef,Sweet,Lamb,Baked]
match_ingred=[]
unmatch=[]
for cat in categ_list:
    for i in cat:
        for elem in i.split(', '):
            elem=lemmatizer.lemmatize(elem)
            if elem in ingredient_list and (elem not in match_ingred):
                match_ingred.append(elem)
            elif (elem not in unmatch):
                unmatch.append(elem)

# %%
np.save('match_ingred', match_ingred)

# %%
match_ingred
# Out:
# ['yam',
#  'taro',
#  'okra',
#  'kale',
#  'onion',
#  'celery',
#  'endive',
#  'garlic',
#  'borage',
#  'chive',
#  'turnip',
#  'cassava',
#  'spinach',
#  'arugula',
#  'cabbage',
#  'carrot',
#  'pumpkin',
#  'kohlrabi',
#  'eggplant',
#  'celeriac',
#  'parsnip',
#  'radish',
#  'shallot',
#  'broccoli',
#  'asparagus',
#  'radicchio',
#  'parsley',
#  'arrowroot',
#  'watercress',
#  'tomatillo',
#  'cauliflower',
#  'pea',
#  'wasabi',
#  'fennel',
#  'chard',
#  'cress',
#  'bamboo shoots',
#  'seaweed',
#  'tomato',
#  'pepper',
#  'banana',
#  'potato',
#  'chayote',
#  'fruit',
#  'mushroom',
#  'morel',
#  'cucumber',
#  'orange',
#  'chicory',
#  'brussels sprouts',
#  'lentil',
#  'jalapeno',
#  'lettuce',
#  'oyster',
#  'pickle',
#  'corn',
#  'bean',
#  'mustard',
#  'tomato juice',
#  'shiitake',
#  'squash',
#  'zucchini',
#  'chanterelle',
#  'scallop',
#  'sweet potato',
#  'chili',
#  'sauce',
#  'spaghetti',
#  'salsify',
#  'artichoke',
#  'potato wedges',
#  'vegetable',
#  'dill',
#  'leek',
#  'oat',
#  'buckwheat',
#  'cornstarch',
#  'millet',
#  'bulgur',
#  'millet flour',
#  'spelt',
#  'couscous',
#  'wild rice',
#  'barley',
#  'quinoa',
#  'rye flour',
#  'rice flour',
#  'semolina',
#  'tapioca',
#  'pasta',
#  'hominy',
#  'noodle',
#  'egg',
#  'rice',
#  'buckwheat flour',
#  'cornmeal',
#  'bread',
#  'macaroni',
#  'cake',
#  'cheese',
#  'feta',
#  'edam',
#  'brie',
#  'cream',
#  'dulce de leche',
#  'butter',
#  'gruyere',
#  'roquefort',
#  'camembert',
#  'milk',
#  'parmesan',
#  'buttermilk',
#  'yogurt',
#  'vanilla',
#  'mozzarella',
#  'ricotta',
#  'duck',
#  'goose',
#  'quail',
#  'turkey',
#  'chocolate',
#  'ice cream',
#  'strawberry',
#  'cheese sauce',
#  'liver',
#  'chicken',
#  'pheasant',
#  'giblet',
#  'heart',
#  'poultry',
#  'turkey breast',
#  'flour',
#  'lard',
#  'oil',
#  'fat',
#  'walnut',
#  'almond',
#  'avocado',
#  'coconut',
#  'hazelnut',
#  'salmon',
#  'cocoa butter',
#  'herring',
#  'sardine',
#  'coleslaw',
#  'mayonnaise',
#  'vegetable oil',
#  'peanut',
#  'olive',
#  'sesame',
#  'soy',
#  'french dressing',
#  'confectionery',
#  'margarine',
#  'salt',
#  'basil',
#  'thyme',
#  'caper',
#  'vinegar',
#  'cider',
#  'spice',
#  'saffron',
#  'vanilla extract',
#  'paprika',
#  'rosemary',
#  'cardamom',
#  'bay leaf',
#  'red wine',
#  'sage',
#  'curry powder',
#  'mace',
#  'chili powder',
#  'horseradish',
#  'savory',
#  'clove',
#  'nutmeg',
#  'oregano',
#  'ginger',
#  'chervil',
#  'tarragon',
#  'marjoram',
#  'cinnamon',
#  'allspice',
#  'turmeric',
#  'taco',
#  'fig',
#  'plum',
#  'pear',
#  'lime',
#  'jujube',
#  'mango',
#  'papaya',
#  'quince',
#  'rhubarb',
#  'kumquat',
#  'apricot',
#  'plantain',
#  'tamarind',
#  'date',
#  'lime juice',
#  'raisin',
#  'breadfruit',
#  'mulberry',
#  'nectarine',
#  'watermelon',
#  'cranberry',
#  'clementine',
#  'blueberry',
#  'lemon juice',
#  'raspberry',
#  'blackberry',
#  'orange juice',
#  'elderberry',
#  'gooseberry',
#  'pomegranate',
#  'melon',
#  'prune juice',
#  'guava',
#  'loganberry',
#  'peach',
#  'cherry',
#  'currant',
#  'grape',
#  'apple',
#  'lemon',
#  'pomegranate juice',
#  'grapefruit juice',
#  'cranberry juice',
#  'pineapple',
#  'syrup',
#  'mangosteen',
#  'grapefruit',
#  'cranberry sauce',
#  'tangerine',
#  'prune',
#  'miso',
#  'tofu',
#  'bacon',
#  'sausage',
#  'hummus',
#  'curd cheese',
#  'frankfurter',
#  'falafel',
#  'vermicelli',
#  'peanut butter',
#  'kidney',
#  'nut',
#  'pecan',
#  'seed',
#  'macadamia nuts',
#  'chestnut',
#  'sesame seeds',
#  'coconut cream',
#  'pork',
#  'ham',
#  'pork loin',
#  'beef',
#  'corned beef',
#  'sweetbread',
#  'suet',
#  'tripe',
#  'tongue',
#  'honey',
#  'jelly',
#  'molasses',
#  'sugar',
#  'pectin',
#  'caramel',
#  'marmalade',
#  'marshmallow',
#  'agave',
#  'milk chocolate',
#  'white chocolate',
#  'veal',
#  'lamb',
#  'boar',
#  'rabbit',
#  'water',
#  'pie',
#  'bagel',
#  'oatmeal',
#  'cracker',
#  'crouton',
#  'muffin',
#  'croissant']
